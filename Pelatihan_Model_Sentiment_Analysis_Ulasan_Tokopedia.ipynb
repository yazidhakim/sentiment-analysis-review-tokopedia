# %%
pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.4.0-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.4.0

# %%
pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.1 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 22.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 35.7 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 9.9 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy, gensim
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1

# %%
pip install sastrawi
# Out:
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.12/dist-packages (1.0.1)

# %% [markdown]
# # 1. Import Library

# %%
from unidecode import unidecode
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,f1_score, classification_report, confusion_matrix
from scipy.sparse import hstack
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from wordcloud import WordCloud

from datasets import Dataset
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer


import csv
import requests
from io import StringIO
import nltk
import pandas as pd
import re, os,string, numpy as np
import joblib, seaborn as sns, matplotlib.pyplot as plt

# %% [markdown]
# # 2. Load Dataset

# %%
reviews_df = pd.read_csv('/content/drive/MyDrive/Scrapping/scrapingtokopedia.csv')

# %%
# Menampilkan dataframe teratas
reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  80ebf9ff-43f3-4db7-b2c9-51175e41608d  Pengguna Google
# 1  ff046e7b-613b-43d8-8fda-cfa0bfc5cc49  Pengguna Google
# 2  40e370ad-2183-4786-a3f0-49772cea7bdb  Pengguna Google
# 3  9cf64c5f-0ed8-4af0-aeac-1c9404274e0d  Pengguna Google
# 4  099bae11-3fbf-4a75-8d7a-3d59ccdcbf10  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Ga konsisten, promo dll gajelas, dapat promo i...      1             16
# 1  susah komplain,, saya ada mau komplain balikki...      1             13
# 2  Maaf Respon TokopediaCare Buruk!!! Lebih serin...      4            686
# 3  Dan akhirnya setelah kira2 hampir 3 tahun saya...      1              7
# 4  untuk tokopedia mohon untuk di perketat soal s...      4              4
#
#   reviewCreatedVersion                   at  \
# 0              3.329.0  2025-09-14 00:41:45
# 1              3.329.0  2025-09-13 21:14:22
# 2              3.328.0  2025-09-05 03:12:13
# 3              3.329.0  2025-09-14 05:41:29
# 4              3.328.0  2025-09-15 05:35:07
#
#                                         replyContent            repliedAt  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Halo Toppers, terima kasih atas rating yang ka...  2024-11-23 04:28:01
# 3                                                NaN                  NaN
# 4  Hai Toppers, Terima kasih untuk rating yang te...  2022-09-22 04:17:27
#
#   appVersion
# 0    3.329.0
# 1    3.329.0
# 2    3.328.0
# 3    3.329.0
# 4    3.328.0

# %%
# Menampilkan informasi dataset
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81000 entries, 0 to 80999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              81000 non-null  object
#  1   userName              81000 non-null  object
#  2   userImage             81000 non-null  object
#  3   content               81000 non-null  object
#  4   score                 81000 non-null  int64
#  5   thumbsUpCount         81000 non-null  int64
#  6   reviewCreatedVersion  57232 non-null  object
#  7   at                    81000 non-null  object
#  8   replyContent          41354 non-null  object
#  9   repliedAt             41354 non-null  object
#  10  appVersion            57232 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 6.8+ MB

# %%
# Menampilkan statistik deskriptif
reviews_df.describe()
# Out:
#               score  thumbsUpCount
# count  81000.000000   81000.000000
# mean       3.184963       7.709222
# std        1.827027      78.235459
# min        1.000000       0.000000
# 25%        1.000000       0.000000
# 50%        4.000000       0.000000
# 75%        5.000000       1.000000
# max        5.000000    9904.000000

# %%
# Menampilkan jumlah data yang mengandung kolom null
reviews_df.isnull().sum()
# Out:
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion    23768
# at                          0
# replyContent            39646
# repliedAt               39646
# appVersion              23768
# dtype: int64

# %% [markdown]
# # 3. Data Cleaning

# %%
#Dataframe baru hasil data cleaning
df_clean = reviews_df.dropna()

# %%
df_clean.isnull().sum()
# Out:
# reviewId                0
# userName                0
# userImage               0
# content                 0
# score                   0
# thumbsUpCount           0
# reviewCreatedVersion    0
# at                      0
# replyContent            0
# repliedAt               0
# appVersion              0
# dtype: int64

# %%
# Menghapus baris yang mengandung duplikat
df_clean= df_clean.drop_duplicates()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31545 entries, 2 to 80998
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              31545 non-null  object
#  1   userName              31545 non-null  object
#  2   userImage             31545 non-null  object
#  3   content               31545 non-null  object
#  4   score                 31545 non-null  int64
#  5   thumbsUpCount         31545 non-null  int64
#  6   reviewCreatedVersion  31545 non-null  object
#  7   at                    31545 non-null  object
#  8   replyContent          31545 non-null  object
#  9   repliedAt             31545 non-null  object
#  10  appVersion            31545 non-null  object
# dtypes: int64(2), object(9)
# memory usage: 2.9+ MB

# %%
# Menghitung banyaknya distribusi score pada ulasan
df_clean['score'].value_counts()
# Out:
# score
# 1    16916
# 5     5333
# 2     3448
# 3     3276
# 4     2572
# Name: count, dtype: int64

# %%
# Vissualisasi distribusi rating score ulasan
df_clean['score'].value_counts().plot(kind='pie',figsize=(10,10), autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
# Mapping label sentiment
def map_label(score):
    if score in [1,2]:
      return "negatif"
    elif score == 3:
      return "netral"
    elif score in [4,5]:
      return "positif"
    else:
      return None
# Menambahkan kolom label score sebagai sentiment
df_clean['label'] = df_clean['score'].apply(map_label)

# %%
df_clean
# Out:
#                                    reviewId         userName  \
# 2      40e370ad-2183-4786-a3f0-49772cea7bdb  Pengguna Google
# 4      099bae11-3fbf-4a75-8d7a-3d59ccdcbf10  Pengguna Google
# 13     87192777-615b-41ff-ad57-008cf627777c  Pengguna Google
# 38     b3bb04f5-b41f-4a80-a917-c3d36ce44f5e  Pengguna Google
# 47     86982069-6df4-46a4-93fc-0443598f6d06  Pengguna Google
# ...                                     ...              ...
# 80989  0b4f7906-0e1f-4c56-8041-e97ccc7c0314  Pengguna Google
# 80990  8cfe536c-9c95-4c0e-897c-e766ebf24153  Pengguna Google
# 80996  d4a7afed-c0cc-47aa-940b-f94f1f25f8f3  Pengguna Google
# 80997  15b3a4a1-3f9f-4259-aa54-1e2fe086bf25  Pengguna Google
# 80998  714a51c5-b4e0-4ab6-9401-ec4a92cfb5c4  Pengguna Google
#
#                                                userImage  \
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# 13     https://play-lh.googleusercontent.com/EGemoI2N...
# 38     https://play-lh.googleusercontent.com/EGemoI2N...
# 47     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 80989  https://play-lh.googleusercontent.com/EGemoI2N...
# 80990  https://play-lh.googleusercontent.com/EGemoI2N...
# 80996  https://play-lh.googleusercontent.com/EGemoI2N...
# 80997  https://play-lh.googleusercontent.com/EGemoI2N...
# 80998  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 2      Maaf Respon TokopediaCare Buruk!!! Lebih serin...      4
# 4      untuk tokopedia mohon untuk di perketat soal s...      4
# 13     males belanja di toped ketika ada barang yg ti...      1
# 38     tulisan nya plus gratis ongkir sepuasnya, eh p...      1
# 47     Gimana sih ini Tokopedia sekarang?Kelihatannya...      3
# ...                                                  ...    ...
# 80989  Smakin kesini kurang nyaman soal pe Ngiriman,,...      2
# 80990  Mudah, terintegrasi lebih banyak, sangat memba...      5
# 80996  Respon terhadap pembeli cepat,pelayanan juga c...      5
# 80997  tampilan nya enak dilihat dan sangat mudah unt...      5
# 80998  saya daftar tokopedia pakai nmr ponsel .gk ada...      1
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 2                686              3.328.0  2025-09-05 03:12:13
# 4                  4              3.328.0  2025-09-15 05:35:07
# 13                29              3.329.0  2025-09-09 23:57:12
# 38                11              3.329.0  2025-09-11 06:16:33
# 47                12              3.328.0  2025-09-10 11:03:59
# ...              ...                  ...                  ...
# 80989              0                3.155  2021-12-19 02:10:20
# 80990              0                3.195  2022-10-22 07:29:46
# 80996              0               3.52.1  2019-12-10 11:22:34
# 80997              0                3.182  2022-07-17 02:41:56
# 80998              1                 3.29  2019-05-07 19:05:49
#
#                                             replyContent            repliedAt  \
# 2      Halo Toppers, terima kasih atas rating yang ka...  2024-11-23 04:28:01
# 4      Hai Toppers, Terima kasih untuk rating yang te...  2022-09-22 04:17:27
# 13     Halo Toppers, terima kasih atas rating yang ka...  2024-10-31 23:40:04
# 38     Halo Toppers, terima kasih atas rating yang ka...  2023-08-09 03:49:01
# 47     Terima kasih sudah mempercayakan Tokopedia seb...  2024-09-02 13:00:21
# ...                                                  ...                  ...
# 80989  Hai Kak Jihan, maaf atas pengalaman bertransak...  2021-12-19 02:31:38
# 80990  Hai Toppers, Terima kasih untuk rating yang te...  2022-10-22 07:57:03
# 80996  Hai Slamet, kami ikut senang ya jika kamu sela...  2020-01-05 07:23:44
# 80997  Hai Toppers, Terima kasih untuk rating yang te...  2022-07-17 03:06:03
# 80998  Hai Arga, mohon maaf atas ketidaknyamanannya. ...  2019-05-08 02:26:01
#
#       appVersion    label
# 2        3.328.0  positif
# 4        3.328.0  positif
# 13       3.329.0  negatif
# 38       3.329.0  negatif
# 47       3.328.0   netral
# ...          ...      ...
# 80989      3.155  negatif
# 80990      3.195  positif
# 80996     3.52.1  positif
# 80997      3.182  positif
# 80998       3.29  negatif
#
# [31545 rows x 12 columns]

# %%
# Distribusi label (negatif,positif,netral)
plt.figure(figsize=(6,4))
sns.countplot(
    x="label",
    data=df_clean,
    order=df_clean["label"].value_counts().index,
    palette="Blues"
)
# Out:
# /tmp/ipython-input-2928627901.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# <Axes: xlabel='label', ylabel='count'>

# %%
# stopwords
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')


# slang map
slangwords = {
    "@":"di","abis":"habis","wtb":"beli","wts":"jual","wtt":"tukar","bgt":"banget",
    "maks":"maksimal","ga":"tidak","gak":"tidak","nggak":"tidak","engga":"tidak","tdk":"tidak"
}

# regex
RE_MENTION = re.compile(r'@[A-Za-z0-9_]+')
RE_HASHTAG = re.compile(r'#[A-Za-z0-9_]+')
RE_RT      = re.compile(r'\bRT\s+')
RE_URL     = re.compile(r'http\S+|www\.\S+')
RE_NUM     = re.compile(r'\d+')
RE_NONALPH = re.compile(r'[^\w\s]')

def clean_basic(text: str) -> str:
    if not isinstance(text, str): return ""
    t = RE_MENTION.sub('', text)
    t = RE_HASHTAG.sub('', t)
    t = RE_RT.sub('', t)
    t = RE_URL.sub('', t)
    t = RE_NUM.sub('', t)
    t = RE_NONALPH.sub(' ', t)
    t = t.replace('\n',' ').translate(str.maketrans('', '', string.punctuation))
    return t.lower().strip()

def stemmingText(text):
    # Membuat objek stemmer
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()

    # Memecah teks menjadi daftar kata
    words = text.split()

    # Menerapkan stemming pada setiap kata dalam daftar
    stemmed_words = [stemmer.stem(word) for word in words]

    # Menggabungkan kata-kata yang telah distem
    stemmed_text = ' '.join(stemmed_words)

    return stemmed_text

def tokenize(text):
    text = word_tokenize(text)
    return text

def filteringText(text): # Menghapus stopwords dalam teks
    listStopwords = set(stopwords.words('indonesian'))
    listStopwords1 = set(stopwords.words('english'))
    listStopwords.update(listStopwords1)
    listStopwords.update(['iya','yaa','gak','nya','na','sih','ku',"di","ga","ya","gaa","loh","kah","woi","woii","woy"])
    filtered = []
    for txt in text:
        if txt not in listStopwords:
            filtered.append(txt)
    text = filtered
    return text


def toSentence(list_words): # Mengubah daftar kata menjadi kalimat
    sentence = ' '.join(word for word in list_words)
    return sentence
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def fix_slangwords(text):
    words = text.split()
    fixed_words = []

    for word in words:
        if word.lower() in slangwords:
            fixed_words.append(slangwords[word.lower()])
        else:
            fixed_words.append(word)

    fixed_text = ' '.join(fixed_words)
    return fixed_text

# %%
# Mengubah huruf dalam teks menjadi huruf kecil
df_clean['text_clean'] = df_clean['content'].apply(clean_basic)

# Mengganti kata-kata slang dengan kata-kata standar
df_clean['text_slangwords'] = df_clean['text_clean'].apply(fix_slangwords)

# Memecah teks menjadi token (kata-kata)
df_clean['text_tokenizingText'] = df_clean['text_slangwords'].apply(tokenize)

# Menghapus kata-kata stop (kata-kata umum)
df_clean['text_stopword'] = df_clean['text_tokenizingText'].apply(filteringText)

# Menggabungkan token-token menjadi kalimat
df_clean['text_akhir'] = df_clean['text_stopword'].apply(toSentence)

# %%
df_clean
# Out:
#                                    reviewId         userName  \
# 2      40e370ad-2183-4786-a3f0-49772cea7bdb  Pengguna Google
# 4      099bae11-3fbf-4a75-8d7a-3d59ccdcbf10  Pengguna Google
# 13     87192777-615b-41ff-ad57-008cf627777c  Pengguna Google
# 38     b3bb04f5-b41f-4a80-a917-c3d36ce44f5e  Pengguna Google
# 47     86982069-6df4-46a4-93fc-0443598f6d06  Pengguna Google
# ...                                     ...              ...
# 80989  0b4f7906-0e1f-4c56-8041-e97ccc7c0314  Pengguna Google
# 80990  8cfe536c-9c95-4c0e-897c-e766ebf24153  Pengguna Google
# 80996  d4a7afed-c0cc-47aa-940b-f94f1f25f8f3  Pengguna Google
# 80997  15b3a4a1-3f9f-4259-aa54-1e2fe086bf25  Pengguna Google
# 80998  714a51c5-b4e0-4ab6-9401-ec4a92cfb5c4  Pengguna Google
#
#                                                userImage  \
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# 13     https://play-lh.googleusercontent.com/EGemoI2N...
# 38     https://play-lh.googleusercontent.com/EGemoI2N...
# 47     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 80989  https://play-lh.googleusercontent.com/EGemoI2N...
# 80990  https://play-lh.googleusercontent.com/EGemoI2N...
# 80996  https://play-lh.googleusercontent.com/EGemoI2N...
# 80997  https://play-lh.googleusercontent.com/EGemoI2N...
# 80998  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 2      Maaf Respon TokopediaCare Buruk!!! Lebih serin...      4
# 4      untuk tokopedia mohon untuk di perketat soal s...      4
# 13     males belanja di toped ketika ada barang yg ti...      1
# 38     tulisan nya plus gratis ongkir sepuasnya, eh p...      1
# 47     Gimana sih ini Tokopedia sekarang?Kelihatannya...      3
# ...                                                  ...    ...
# 80989  Smakin kesini kurang nyaman soal pe Ngiriman,,...      2
# 80990  Mudah, terintegrasi lebih banyak, sangat memba...      5
# 80996  Respon terhadap pembeli cepat,pelayanan juga c...      5
# 80997  tampilan nya enak dilihat dan sangat mudah unt...      5
# 80998  saya daftar tokopedia pakai nmr ponsel .gk ada...      1
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 2                686              3.328.0  2025-09-05 03:12:13
# 4                  4              3.328.0  2025-09-15 05:35:07
# 13                29              3.329.0  2025-09-09 23:57:12
# 38                11              3.329.0  2025-09-11 06:16:33
# 47                12              3.328.0  2025-09-10 11:03:59
# ...              ...                  ...                  ...
# 80989              0                3.155  2021-12-19 02:10:20
# 80990              0                3.195  2022-10-22 07:29:46
# 80996              0               3.52.1  2019-12-10 11:22:34
# 80997              0                3.182  2022-07-17 02:41:56
# 80998              1                 3.29  2019-05-07 19:05:49
#
#                                             replyContent            repliedAt  \
# 2      Halo Toppers, terima kasih atas rating yang ka...  2024-11-23 04:28:01
# 4      Hai Toppers, Terima kasih untuk rating yang te...  2022-09-22 04:17:27
# 13     Halo Toppers, terima kasih atas rating yang ka...  2024-10-31 23:40:04
# 38     Halo Toppers, terima kasih atas rating yang ka...  2023-08-09 03:49:01
# 47     Terima kasih sudah mempercayakan Tokopedia seb...  2024-09-02 13:00:21
# ...                                                  ...                  ...
# 80989  Hai Kak Jihan, maaf atas pengalaman bertransak...  2021-12-19 02:31:38
# 80990  Hai Toppers, Terima kasih untuk rating yang te...  2022-10-22 07:57:03
# 80996  Hai Slamet, kami ikut senang ya jika kamu sela...  2020-01-05 07:23:44
# 80997  Hai Toppers, Terima kasih untuk rating yang te...  2022-07-17 03:06:03
# 80998  Hai Arga, mohon maaf atas ketidaknyamanannya. ...  2019-05-08 02:26:01
#
#       appVersion    label                                         text_clean  \
# 2        3.328.0  positif  maaf respon tokopediacare buruk    lebih serin...
# 4        3.328.0  positif  untuk tokopedia mohon untuk di perketat soal s...
# 13       3.329.0  negatif  males belanja di toped ketika ada barang yg ti...
# 38       3.329.0  negatif  tulisan nya plus gratis ongkir sepuasnya  eh p...
# 47       3.328.0   netral  gimana sih ini tokopedia sekarang kelihatannya...
# ...          ...      ...                                                ...
# 80989      3.155  negatif  smakin kesini kurang nyaman soal pe ngiriman  ...
# 80990      3.195  positif  mudah  terintegrasi lebih banyak  sangat memba...
# 80996     3.52.1  positif  respon terhadap pembeli cepat pelayanan juga c...
# 80997      3.182  positif  tampilan nya enak dilihat dan sangat mudah unt...
# 80998       3.29  negatif  saya daftar tokopedia pakai nmr ponsel  gk ada...
#
#                                          text_slangwords  \
# 2      maaf respon tokopediacare buruk lebih sering d...
# 4      untuk tokopedia mohon untuk di perketat soal s...
# 13     males belanja di toped ketika ada barang yg ti...
# 38     tulisan nya plus gratis ongkir sepuasnya eh pa...
# 47     gimana sih ini tokopedia sekarang kelihatannya...
# ...                                                  ...
# 80989  smakin kesini kurang nyaman soal pe ngiriman k...
# 80990  mudah terintegrasi lebih banyak sangat membant...
# 80996  respon terhadap pembeli cepat pelayanan juga c...
# 80997  tampilan nya enak dilihat dan sangat mudah unt...
# 80998  saya daftar tokopedia pakai nmr ponsel gk ada ...
#
#                                      text_tokenizingText  \
# 2      [maaf, respon, tokopediacare, buruk, lebih, se...
# 4      [untuk, tokopedia, mohon, untuk, di, perketat,...
# 13     [males, belanja, di, toped, ketika, ada, baran...
# 38     [tulisan, nya, plus, gratis, ongkir, sepuasnya...
# 47     [gimana, sih, ini, tokopedia, sekarang, keliha...
# ...                                                  ...
# 80989  [smakin, kesini, kurang, nyaman, soal, pe, ngi...
# 80990  [mudah, terintegrasi, lebih, banyak, sangat, m...
# 80996  [respon, terhadap, pembeli, cepat, pelayanan, ...
# 80997  [tampilan, nya, enak, dilihat, dan, sangat, mu...
# 80998  [saya, daftar, tokopedia, pakai, nmr, ponsel, ...
#
#                                            text_stopword  \
# 2      [maaf, respon, tokopediacare, buruk, robot, ta...
# 4      [tokopedia, mohon, perketat, stok, barang, mar...
# 13     [males, belanja, toped, barang, yg, sesuai, re...
# 38     [tulisan, plus, gratis, ongkir, sepuasnya, eh,...
# 47     [gimana, tokopedia, kupon, voucher, kebanyakan...
# ...                                                  ...
# 80989  [smakin, kesini, nyaman, pe, ngiriman, kl, top...
# 80990            [mudah, terintegrasi, membantu, mantap]
# 80996  [respon, pembeli, cepat, pelayanan, cepat, tok...
# 80997                            [tampilan, enak, mudah]
# 80998  [daftar, tokopedia, pakai, nmr, ponsel, gk, pa...
#
#                                               text_akhir
# 2      maaf respon tokopediacare buruk robot tampilan...
# 4      tokopedia mohon perketat stok barang market be...
# 13     males belanja toped barang yg sesuai return su...
# 38     tulisan plus gratis ongkir sepuasnya eh pas ce...
# 47     gimana tokopedia kupon voucher kebanyakan dipa...
# ...                                                  ...
# 80989  smakin kesini nyaman pe ngiriman kl toped udah...
# 80990                 mudah terintegrasi membantu mantap
# 80996  respon pembeli cepat pelayanan cepat toko pedi...
# 80997                                tampilan enak mudah
# 80998  daftar tokopedia pakai nmr ponsel gk panduan b...
#
# [31545 rows x 17 columns]

# %%
# Membaca data kamus kata-kata positif dari GitHub
lexicon_positive = dict()

response = requests.get('https://raw.githubusercontent.com/angelmetanosaa/dataset/main/lexicon_positive.csv')

if response.status_code == 200:
    # Jika permintaan berhasil
    reader = csv.reader(StringIO(response.text), delimiter=',')

    for row in reader:
        lexicon_positive[row[0]] = int(row[1])
        # Menambahkan kata-kata positif dan skornya ke dalam kamus lexicon_positive
else:
    print("Failed to fetch positive lexicon data")

# Membaca data kamus kata-kata negatif dari GitHub
lexicon_negative = dict()

response = requests.get('https://raw.githubusercontent.com/angelmetanosaa/dataset/main/lexicon_negative.csv')
# Mengirim permintaan HTTP untuk mendapatkan file CSV dari GitHub

if response.status_code == 200:
    # Jika permintaan berhasil
    reader = csv.reader(StringIO(response.text), delimiter=',')
    # Membaca teks respons sebagai file CSV menggunakan pembaca CSV dengan pemisah koma

    for row in reader:
        # Mengulangi setiap baris dalam file CSV
        lexicon_negative[row[0]] = int(row[1])
        # Menambahkan kata-kata negatif dan skornya dalam kamus lexicon_negative
else:
    print("Failed to fetch negative lexicon data")

# %%
def sentiment_analysis_lexicon_indonesia(text):
    score = 0

    for word in text:

        if (word in lexicon_positive):
            score = score + lexicon_positive[word]
            # Jika kata ada dalam kamus positif, tambahkan skornya ke skor sentimen

    for word in text:

        if (word in lexicon_negative):
            score = score + lexicon_negative[word]

    polarity=''
    # Inisiasi polaritas

    if (score >= 0):
        polarity = 'positive'
    elif (score < 0):
        polarity = 'negative'
    else:
        polarity = 'neutral'


    return score, polarity

# %%
results = df_clean['text_stopword'].apply(sentiment_analysis_lexicon_indonesia)
results = list(zip(*results))
df_clean['polarity_score'] = results[0]
df_clean['polarity'] = results[1]
print(df_clean['polarity'].value_counts())
# Out:
# polarity
# negative    16305
# positive    15240
# Name: count, dtype: int64

# %%
for label in df_clean["polarity"].unique():
    text = " ".join(df_clean[df_clean["polarity"] == label]["text_stopword"].astype(str))

    wc = WordCloud(
        width=800,
        height=400,
        background_color="white",
        colormap="coolwarm",
        collocations=False
    ).generate(text)

    plt.figure(figsize=(12,6))
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(f"Word Cloud - Label: {label}")
    plt.show()

# %%
df_clean
# Out:
#                                    reviewId         userName  \
# 2      40e370ad-2183-4786-a3f0-49772cea7bdb  Pengguna Google
# 4      099bae11-3fbf-4a75-8d7a-3d59ccdcbf10  Pengguna Google
# 13     87192777-615b-41ff-ad57-008cf627777c  Pengguna Google
# 38     b3bb04f5-b41f-4a80-a917-c3d36ce44f5e  Pengguna Google
# 47     86982069-6df4-46a4-93fc-0443598f6d06  Pengguna Google
# ...                                     ...              ...
# 80989  0b4f7906-0e1f-4c56-8041-e97ccc7c0314  Pengguna Google
# 80990  8cfe536c-9c95-4c0e-897c-e766ebf24153  Pengguna Google
# 80996  d4a7afed-c0cc-47aa-940b-f94f1f25f8f3  Pengguna Google
# 80997  15b3a4a1-3f9f-4259-aa54-1e2fe086bf25  Pengguna Google
# 80998  714a51c5-b4e0-4ab6-9401-ec4a92cfb5c4  Pengguna Google
#
#                                                userImage  \
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# 13     https://play-lh.googleusercontent.com/EGemoI2N...
# 38     https://play-lh.googleusercontent.com/EGemoI2N...
# 47     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 80989  https://play-lh.googleusercontent.com/EGemoI2N...
# 80990  https://play-lh.googleusercontent.com/EGemoI2N...
# 80996  https://play-lh.googleusercontent.com/EGemoI2N...
# 80997  https://play-lh.googleusercontent.com/EGemoI2N...
# 80998  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 2      Maaf Respon TokopediaCare Buruk!!! Lebih serin...      4
# 4      untuk tokopedia mohon untuk di perketat soal s...      4
# 13     males belanja di toped ketika ada barang yg ti...      1
# 38     tulisan nya plus gratis ongkir sepuasnya, eh p...      1
# 47     Gimana sih ini Tokopedia sekarang?Kelihatannya...      3
# ...                                                  ...    ...
# 80989  Smakin kesini kurang nyaman soal pe Ngiriman,,...      2
# 80990  Mudah, terintegrasi lebih banyak, sangat memba...      5
# 80996  Respon terhadap pembeli cepat,pelayanan juga c...      5
# 80997  tampilan nya enak dilihat dan sangat mudah unt...      5
# 80998  saya daftar tokopedia pakai nmr ponsel .gk ada...      1
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 2                686              3.328.0  2025-09-05 03:12:13
# 4                  4              3.328.0  2025-09-15 05:35:07
# 13                29              3.329.0  2025-09-09 23:57:12
# 38                11              3.329.0  2025-09-11 06:16:33
# 47                12              3.328.0  2025-09-10 11:03:59
# ...              ...                  ...                  ...
# 80989              0                3.155  2021-12-19 02:10:20
# 80990              0                3.195  2022-10-22 07:29:46
# 80996              0               3.52.1  2019-12-10 11:22:34
# 80997              0                3.182  2022-07-17 02:41:56
# 80998              1                 3.29  2019-05-07 19:05:49
#
#                                             replyContent            repliedAt  \
# 2      Halo Toppers, terima kasih atas rating yang ka...  2024-11-23 04:28:01
# 4      Hai Toppers, Terima kasih untuk rating yang te...  2022-09-22 04:17:27
# 13     Halo Toppers, terima kasih atas rating yang ka...  2024-10-31 23:40:04
# 38     Halo Toppers, terima kasih atas rating yang ka...  2023-08-09 03:49:01
# 47     Terima kasih sudah mempercayakan Tokopedia seb...  2024-09-02 13:00:21
# ...                                                  ...                  ...
# 80989  Hai Kak Jihan, maaf atas pengalaman bertransak...  2021-12-19 02:31:38
# 80990  Hai Toppers, Terima kasih untuk rating yang te...  2022-10-22 07:57:03
# 80996  Hai Slamet, kami ikut senang ya jika kamu sela...  2020-01-05 07:23:44
# 80997  Hai Toppers, Terima kasih untuk rating yang te...  2022-07-17 03:06:03
# 80998  Hai Arga, mohon maaf atas ketidaknyamanannya. ...  2019-05-08 02:26:01
#
#       appVersion    label                                         text_clean  \
# 2        3.328.0  positif  maaf respon tokopediacare buruk    lebih serin...
# 4        3.328.0  positif  untuk tokopedia mohon untuk di perketat soal s...
# 13       3.329.0  negatif  males belanja di toped ketika ada barang yg ti...
# 38       3.329.0  negatif  tulisan nya plus gratis ongkir sepuasnya  eh p...
# 47       3.328.0   netral  gimana sih ini tokopedia sekarang kelihatannya...
# ...          ...      ...                                                ...
# 80989      3.155  negatif  smakin kesini kurang nyaman soal pe ngiriman  ...
# 80990      3.195  positif  mudah  terintegrasi lebih banyak  sangat memba...
# 80996     3.52.1  positif  respon terhadap pembeli cepat pelayanan juga c...
# 80997      3.182  positif  tampilan nya enak dilihat dan sangat mudah unt...
# 80998       3.29  negatif  saya daftar tokopedia pakai nmr ponsel  gk ada...
#
#                                          text_slangwords  \
# 2      maaf respon tokopediacare buruk lebih sering d...
# 4      untuk tokopedia mohon untuk di perketat soal s...
# 13     males belanja di toped ketika ada barang yg ti...
# 38     tulisan nya plus gratis ongkir sepuasnya eh pa...
# 47     gimana sih ini tokopedia sekarang kelihatannya...
# ...                                                  ...
# 80989  smakin kesini kurang nyaman soal pe ngiriman k...
# 80990  mudah terintegrasi lebih banyak sangat membant...
# 80996  respon terhadap pembeli cepat pelayanan juga c...
# 80997  tampilan nya enak dilihat dan sangat mudah unt...
# 80998  saya daftar tokopedia pakai nmr ponsel gk ada ...
#
#                                      text_tokenizingText  \
# 2      [maaf, respon, tokopediacare, buruk, lebih, se...
# 4      [untuk, tokopedia, mohon, untuk, di, perketat,...
# 13     [males, belanja, di, toped, ketika, ada, baran...
# 38     [tulisan, nya, plus, gratis, ongkir, sepuasnya...
# 47     [gimana, sih, ini, tokopedia, sekarang, keliha...
# ...                                                  ...
# 80989  [smakin, kesini, kurang, nyaman, soal, pe, ngi...
# 80990  [mudah, terintegrasi, lebih, banyak, sangat, m...
# 80996  [respon, terhadap, pembeli, cepat, pelayanan, ...
# 80997  [tampilan, nya, enak, dilihat, dan, sangat, mu...
# 80998  [saya, daftar, tokopedia, pakai, nmr, ponsel, ...
#
#                                            text_stopword  \
# 2      [maaf, respon, tokopediacare, buruk, robot, ta...
# 4      [tokopedia, mohon, perketat, stok, barang, mar...
# 13     [males, belanja, toped, barang, yg, sesuai, re...
# 38     [tulisan, plus, gratis, ongkir, sepuasnya, eh,...
# 47     [gimana, tokopedia, kupon, voucher, kebanyakan...
# ...                                                  ...
# 80989  [smakin, kesini, nyaman, pe, ngiriman, kl, top...
# 80990            [mudah, terintegrasi, membantu, mantap]
# 80996  [respon, pembeli, cepat, pelayanan, cepat, tok...
# 80997                            [tampilan, enak, mudah]
# 80998  [daftar, tokopedia, pakai, nmr, ponsel, gk, pa...
#
#                                               text_akhir  polarity_score  \
# 2      maaf respon tokopediacare buruk robot tampilan...              -8
# 4      tokopedia mohon perketat stok barang market be...               4
# 13     males belanja toped barang yg sesuai return su...              -9
# 38     tulisan plus gratis ongkir sepuasnya eh pas ce...               5
# 47     gimana tokopedia kupon voucher kebanyakan dipa...              11
# ...                                                  ...             ...
# 80989  smakin kesini nyaman pe ngiriman kl toped udah...               2
# 80990                 mudah terintegrasi membantu mantap               8
# 80996  respon pembeli cepat pelayanan cepat toko pedi...               5
# 80997                                tampilan enak mudah               5
# 80998  daftar tokopedia pakai nmr ponsel gk panduan b...               6
#
#        polarity
# 2      negative
# 4      positive
# 13     negative
# 38     positive
# 47     positive
# ...         ...
# 80989  positive
# 80990  positive
# 80996  positive
# 80997  positive
# 80998  positive
#
# [31545 rows x 19 columns]

# %% [markdown]
# # 4. Skema 1 ( SVM + TF-IDF )

# %%
# Train/Test Split
X = df_clean["text_akhir"].values
y = df_clean["polarity"].values

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=59,
    stratify=y
)
print(len(X_train), len(X_test))
# Out:
# 25236 6309

# %%
pipeline = make_pipeline(
    TfidfVectorizer(
        max_features=30000,
        min_df=17,
        max_df=0.8
    ),
    LinearSVC(random_state=59)
)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer',
#                  TfidfVectorizer(max_df=0.8, max_features=30000, min_df=17)),
#                 ('linearsvc', LinearSVC(random_state=59))])

# %%
y_pred = pipeline.predict(X_test)
print("Accuracy:", round(accuracy_score(y_test, y_pred)*100, 2), "%")
print(classification_report(y_test, y_pred, digits=3))
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 92.71 %
#               precision    recall  f1-score   support
#
#     negative      0.926     0.933     0.930      3261
#     positive      0.928     0.921     0.924      3048
#
#     accuracy                          0.927      6309
#    macro avg      0.927     0.927     0.927      6309
# weighted avg      0.927     0.927     0.927      6309
#
# Confusion matrix:
#  [[3043  218]
#  [ 242 2806]]

# %% [markdown]
# # 5. Skema 2 ( Logistic Regression + BoW)

# %%
X = df_clean["text_akhir"].values
y = df_clean["polarity"].values

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=59,
    stratify=y
)

# %%
pipe_lr = Pipeline([
    ("vect", CountVectorizer(max_features=30000, ngram_range=(1,2))),
    ("clf", LogisticRegression(
        max_iter=2000,
        n_jobs=-1,
        solver="saga"
    ))
])

# %%
pipe_lr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vect',
#                  CountVectorizer(max_features=30000, ngram_range=(1, 2))),
#                 ('clf',
#                  LogisticRegression(max_iter=2000, n_jobs=-1, solver='saga'))])

# %%
y_pred = pipe_lr.predict(X_test)
print("Accuracy:", round(accuracy_score(y_test, y_pred)*100, 2), "%")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Accuracy: 90.88 %
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     negative      0.913     0.910     0.912      4892
#     positive      0.904     0.907     0.906      4572
#
#     accuracy                          0.909      9464
#    macro avg      0.909     0.909     0.909      9464
# weighted avg      0.909     0.909     0.909      9464

# %%
pip freeze > requirements.txt
