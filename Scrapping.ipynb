# %% [markdown]
# # 1. SCRAPPING DATA

# %%
pip install google-play-scraper

# %%
from google_play_scraper import Sort, reviews_all
from pathlib import Path
import csv
import pandas as pd

# %%
scrapreview = reviews_all(
    'com.tokopedia.tkpd',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=100000
)

# %%
with open('scrapingtokopedia.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview:
        writer.writerow([review['content']])

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.to_csv('/content/scrapingtokopedia.csv', index=False)

# %%
#Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# %%
# Menghitung jumlah kolom dan baris pada dataframe
count_comment, count_column = app_reviews_df.shape

# %% [markdown]
# # 2. INFORMASI DATASET

# %%
app_reviews_df
# Out:
#                                    reviewId         userName  \
# 0      80ebf9ff-43f3-4db7-b2c9-51175e41608d  Pengguna Google
# 1      ff046e7b-613b-43d8-8fda-cfa0bfc5cc49  Pengguna Google
# 2      40e370ad-2183-4786-a3f0-49772cea7bdb  Pengguna Google
# 3      9cf64c5f-0ed8-4af0-aeac-1c9404274e0d  Pengguna Google
# 4      099bae11-3fbf-4a75-8d7a-3d59ccdcbf10  Pengguna Google
# ...                                     ...              ...
# 80995  d7975733-5d90-4356-b1ae-75fc9d79292e  Pengguna Google
# 80996  d4a7afed-c0cc-47aa-940b-f94f1f25f8f3  Pengguna Google
# 80997  15b3a4a1-3f9f-4259-aa54-1e2fe086bf25  Pengguna Google
# 80998  714a51c5-b4e0-4ab6-9401-ec4a92cfb5c4  Pengguna Google
# 80999  8d234a65-7d0c-4b8f-b5b3-c5b74d133154  Pengguna Google
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  80ebf9ff-43f3-4db7-b2c9-51175e41608d  Pengguna Google
# 1  ff046e7b-613b-43d8-8fda-cfa0bfc5cc49  Pengguna Google
# 2  40e370ad-2183-4786-a3f0-49772cea7bdb  Pengguna Google
# 3  9cf64c5f-0ed8-4af0-aeac-1c9404274e0d  Pengguna Google
# 4  099bae11-3fbf-4a75-8d7a-3d59ccdcbf10  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Ga konsisten, promo dll gajelas, dapat promo i...      1             16
# 1  susah komplain,, saya ada mau komplain balikki...      1             13
# ...

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81000 entries, 0 to 80999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              81000 non-null  object
#  1   userName              81000 non-null  object
#  2   userImage             81000 non-null  object
#  3   content               81000 non-null  object
#  4   score                 81000 non-null  int64
#  5   thumbsUpCount         81000 non-null  int64
#  6   reviewCreatedVersion  57232 non-null  object
#  7   at                    81000 non-null  datetime64[ns]
#  8   replyContent          41354 non-null  object
#  9   repliedAt             41354 non-null  datetime64[ns]
#  10  appVersion            57232 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 6.8+ MB
